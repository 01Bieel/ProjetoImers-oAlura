# %% [markdown]
# <a href="https://colab.research.google.com/github/01Bieel/ProjetoImers-oAlura/blob/main/PROJETO_ALURA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U -q google-generativeai

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Importações e configurações iniciais
import numpy as np
import pandas as pd
import google.generativeai as genai

GOOGLE_API_KEY='Insira sua API KEY'
genai.configure(api_key=GOOGLE_API_KEY)

# %%
for m in genai.list_models():
  if 'embedContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/embedding-001
# models/text-embedding-004

# %%
#Exemplo de embedding
title = "A próxima geração de IA para desenvolvedores e Google Workspace"
sample_text = ("Título: A próxima geração de IA para desenvolvedores e Google Workspace"
    "\n"
    "Artigo completo:\n"
    "\n"
    "Gemini API & Google AI Studio: Uma maneira acessível de explorar e criar protótipos com aplicações de IA generativa")

embeddings = genai.embed_content(model="models/embedding-001",
                                 content=sample_text,
                                 title=title,
                                 task_type="RETRIEVAL_DOCUMENT")

print(embeddings)
# Out:
# {'embedding': [0.051496185, -0.0365346, -0.0186796, 0.019455563, 0.06721682, -0.003868702, -0.027666211, -0.01814636, 0.062080767, 0.062902406, 0.012042811, 0.01314806, -0.045869622, -0.022034725, 0.009636108, -0.024947647, 0.021764254, -0.011328052, -0.03484635, -0.00094051583, 0.009192941, 0.0068539544, -0.029636258, -0.06623153, -0.019914951, 0.020645097, 0.015273816, -0.038156737, -0.032827046, 0.02755795, -0.049995217, 0.05074531, -0.034130614, 0.010284468, -0.036612358, -0.040648427, -0.026028484, -0.044465132, -0.002034308, -0.0036913794, 0.0061324253, -0.084707916, -0.009676676, 0.02611583, -0.0035269416, -0.021471972, 0.04472568, 0.04406418, 0.01429429, -0.058487777, 0.027538216, 0.023262272, 0.066298164, -0.041965708, -0.0041519217, -0.009309915, 0.022716599, -0.032830838, 0.02376307, 0.0006589484, -0.0012957085, 0.023344554, -0.016953444, 0.052708756, 0.01914495, -0.05771819, -0.04336735, -9.953024e-05, 0.011018355, 0.048855364, 0.009574091, 0.012556762, 0.060748216, -0.06
# ...

# %%
#Listagem de documentos que serão buscados
DOCUMENT1 = {
    "Título": "Identificar o Problema",
    "Conteúdo": "Descreva o problema em detalhes: O que está acontecendo? Quando o problema começou? O que você estava fazendo quando o problema ocorreu? Observe os erros: Anote todas as mensagens de erro que aparecem na tela. Verifique a conectividade: Certifique-se de que o computador esteja conectado à tomada e à internet (se necessário).verifique o log do sistema,  Os logs do sistema podem conter informações úteis sobre o problema. Reinicie o computador: Muitas vezes, um simples reinício pode resolver o problema."}

DOCUMENT2 = {
    "Título": "O computador nao liga",
    "Conteúdo": "O computador nao liga? Solução: Verifique se o cabo de força está conectado à tomada e ao computador. Pressione o botão liga/desliga por alguns segundos. Se o computador ainda não ligar, tente conectá-lo a outra tomada ou use um cabo de força diferente."}
DOCUMENT3 = {
    "Título": "O que é bios",
    "Conteúdo": "A BIOS é como o cérebro inicial do seu computador. Ela é um pequeno programa gravado num chip na placa-mãe. Em poucas palavras, a BIOS: Acorda o computador quando você o liga. Checa se todos os componentes vitais (memória, processador, etc.) estão funcionando. Carrega o sistema operacional (Windows, Linux, etc.) do disco rígido para a memória. Sem a BIOS, o computador não saberia por onde começar a funcionar!"}

DOCUMENT4 = {
    "Título": "Buscar Mais Ajuda",
    "Conteúdo": "Se você seguiu todos os passos acima e o problema persistir, entre em contato com o suporte técnico de seu fabricante ou de um profissional qualificado. Dicas Adicionais Mantenha o sistema operacional e os programas atualizados. Faça backup dos seus dados regularmente. Use um antivírus e um firewall para proteger seu computador. Tenha cuidado ao baixar arquivos da internet. Não abra anexos de email suspeitos." }

DOCUMENT5 = {
    "Título": "O computador liga, mas não inicializa.",
    "Conteúdo": "Solução: Tente entrar na BIOS. Se conseguir, verifique a ordem de inicialização e certifique-se de que o disco rígido com o sistema operacional esteja listado como primeiro dispositivo de inicialização. Se não conseguir entrar na BIOS ou se o problema persistir, tente reinstalar o sistema operacional." }


DOCUMENT6 = {
    "Título": "O computador está lento",
    "Conteúdo": "Solução: Feche todos os programas desnecessários que estejam em execução. Desinstale programas que você não usa mais. Libere espaço no disco rígido. Verifique se há vírus ou malware no computador. Desfragmente o disco rígido."}


DOCUMENT7 =  {
    "Título": "O computador está congelando",
    "Conteúdo": "Solução: Tente fechar todos os programas desnecessários que estejam em execução. Atualize os drivers do sistema. Verifique se há vírus ou malware no computador. Aumente a memória RAM do computador."}

DOCUMENT8 =  {
    "Título": "A tela está preta",
    "Conteúdo": "Solução: Verifique se o monitor está ligado e conectado ao computador. Ajuste o brilho do monitor. Tente conectar o computador a outro monitor. Se o problema persistir, pode haver um problema com a placa de vídeo."}

DOCUMENT9 =  {
    "Título": "Verificação de logs do Sistema",
     "Conteúdo":"Verifique os logs do sistema:** Os logs do sistema podem conter informações úteis sobre o problema. Para acessar os logs do sistema, siga estas etapas: 1. Pressione **Windows + R** para abrir a caixa de diálogo Executar.   2. Digite **eventvwr.msc** e pressione Enter.    3. Expanda os logs no painel esquerdo e clique com o botão direito do mouse no log **Aplicativo**.    4. Selecione **Propriedades** no menu de contexto.    5. Na guia **Geral**, marque a caixa de seleção **Registrar eventos em um arquivo de log** e especifique um local para salvar o arquivo de log.    6. Clique em **OK**.   7. Reproduza o problema e, em seguida, abra o arquivo de log para verificar se há erros ou avisos relevantes."}

DOCUMENT10 =  {
    "Título": "Ferramentas de diagnósticos",
     "Conteúdo":"Execute ferramentas de diagnóstico:** O Windows possui várias ferramentas de diagnóstico que podem ajudar a identificar a causa do problema. Para acessar essas ferramentas, siga estas etapas:   1. Pressione Windows + X para abrir o menu Iniciar avançado.   2. Clique em Prompt de Comando (Admin).    3. Digite o seguinte comando e pressione Enter:   chkdsk C: /f /r    Observação: Substitua C: pela letra da unidade que você deseja verificar.   4. Digite o seguinte comando e pressione Enter:  sfc /scannow  5. Reinicie o computador e verifique se o problema persiste. "}


DOCUMENT11 =  {
    "Título": "Problema de desempenho",
     "Conteúdo":"Problemas de desempenho:  Verifique o uso da memória e do disco rígido. Para fazer isso, siga estas etapas: 1. Pressione **Ctrl + Shift + Esc** para abrir o Gerenciador de Tarefas. 2. Na guia **Desempenho**, visualize o uso da memória e do disco rígido.   Se a memória ou o disco rígido estiverem quase cheios, libere espaço excluindo arquivos desnecessários, esvaziando a lixeira e desinstalando programas que você não usa mais.  Você também pode tentar atualizar o Windows para a versão mais recente, pois isso pode incluir melhorias de desempenho. Se você já liberou espaço em disco e atualizou o Windows, você pode tentar desativar alguns programas de inicialização que podem estar consumindo recursos do sistema. Para fazer isso, siga estas etapas:  1. Pressione **Windows + R** para abrir a caixa de diálogo Executar.  2. Digite **msconfig** e pressione Enter. 3. Na guia **Inicialização**, desmarque a caixa de seleção ao lado dos programas que você deseja desativar. 4. Clique em **OK**.  5. Reinicie o computador. Você também pode tentar fazer um upgrade da memória RAM do seu computador"}


DOCUMENT12 =  {
    "Título": "Verificação de arquivos corrompidos",
     "Conteúdo":"Verifique se há arquivos corrompidos no sistema.** Para fazer isso, siga estas etapas:    1. Pressione Windows + X para abrir o menu Iniciar avançado.    2. Clique em Prompt de Comando (Admin).    3. Digite o seguinte comando e pressione Enter:   sfc /scannow  Observação: Se o comando sfc encontrar arquivos corrompidos, ele tentará repará-los automaticamente.   4. Se o comando **sfc** não conseguir reparar os arquivos corrompidos, você precisará usar a ferramenta **DISM** para reparar a imagem do sistema. Para fazer isso, siga estas etapas:  1. Digite o seguinte comando e pressione Enter:  DISM.exe /Online /Cleanup-image /Restorehealt  Observação: Este comando pode levar algum tempo para ser concluído. 2. Depois que o comando **DISM** for concluído, digite o seguinte comando e pressione Enter:  sfc /scannow "}


DOCUMENT13 =  {
    "Título": "Verificação de drivers",
     "Conteúdo":"Pressione Windows + X para abrir o menu Iniciar avançado.   2. Clique em **Gerenciador de Dispositivos.   3. Expanda as categorias de dispositivos no Gerenciador de Dispositivos e procure por dispositivos com um ponto de exclamação amarelo.   4. Clique com o botão direito do mouse em um dispositivo com um ponto de exclamação amarelo e selecione **Propriedades**. 5. Na guia Driver, clique em Atualizar driver. 6. Siga as instruções para atualizar o driver. Execute testes de diagnóstico de hardware. A maioria dos computadores possui ferramentas de diagnóstico de hardware embutidas. Para acessar essas ferramentas, consulte o manual do usuário do seu computador ou o site do fabricante. Você também pode usar ferramentas de diagnóstico de terceiros para testar o hardware do seu computador."}


DOCUMENT14 =  {
    "Título": "Problemas de inicialização",
     "Conteúdo":"Problemas de inicialização:  Se você conseguir inicializar o computador no modo de segurança, tente restaurar o sistema para um ponto anterior em que o problema não estava ocorrendo. Para fazer isso, siga estas etapas: 1. Pressione Windows + R para abrir a caixa de diálogo Executar. 2. Digite rstrui.exe e pressione Enter. 3. Siga as instruções na tela para restaurar o sistema.  Se você não conseguir inicializar o computador no modo de segurança, tente reparar a instalação do Windows. Se a reparação da instalação do Windows não funcionar, você precisará reinstalar o Windows. Se você não conseguir inicializar o computador de nenhuma maneira, você precisará usar uma mídia de recuperação para inicializar o computador e reparar a instalação do Windows ou reinstalar o sistema operacional. Você também pode tentar inicializar o computador a partir de um disco Linux live para acessar os arquivos do sistema e tentar diagnosticar o problema. Problemas de desempenho: Se você já desativou programas de inicialização, atualizou o Windows e fez um upgrade da memória RAM, você pode tentar fazer um overclock do processador ou da placa de vídeo do seu computador. **Observação:** O overclock pode danificar o hardware do seu computador, portanto, faça isso apenas se você estiver confiante de suas habilidades e se tiver os componentes de hardware adequados.**  Você também pode tentar instalar um SSD (unidade de estado sólido) no seu computador. Os SSDs são muito mais rápidos do que os discos rígidos tradicionais e podem melhorar significativamente o desempenho do seu computador."}



DOCUMENT15 =  {
    "Título": "Análise Avançada do Problema",
     "Conteúdo":"Colabore com o suporte técnico do fabricante do seu computador.** Eles podem ter acesso a ferramentas de diagnóstico e informações adicionais que podem ajudar a identificar a causa do problema. Analise os arquivos de log do sistema em busca de padrões ou pistas que possam indicar a causa do problema. Use ferramentas de monitoramento de sistema para rastrear o desempenho do computador e identificar possíveis problemas. Execute testes de estresse no hardware do computador para verificar se há falhas. Considere a possibilidade de um problema de software.** Tente reinstalar o sistema operacional ou instalar uma versão diferente do sistema operacional."}

documents = [DOCUMENT1, DOCUMENT2, DOCUMENT3,DOCUMENT4, DOCUMENT5, DOCUMENT6, DOCUMENT7, DOCUMENT8, DOCUMENT9, DOCUMENT10, DOCUMENT11, DOCUMENT12, DOCUMENT13, DOCUMENT14, DOCUMENT15 ]

# %%
df = pd.DataFrame(documents)
df.columns = ["Titulo", "Conteudo"]
df
# Out:
#                                     Titulo  \
# 0                   Identificar o Problema
# 1                    O computador nao liga
# 2                             O que é bios
# 3                        Buscar Mais Ajuda
# 4   O computador liga, mas não inicializa.
# 5                  O computador está lento
# 6             O computador está congelando
# 7                        A tela está preta
# 8           Verificação de logs do Sistema
# 9              Ferramentas de diagnósticos
# 10                  Problema de desempenho
# 11     Verificação de arquivos corrompidos
# 12                  Verificação de drivers
# 13              Problemas de inicialização
# 14            Análise Avançada do Problema
#
#                                              Conteudo
# 0   Descreva o problema em detalhes: O que está ac...
# 1   O computador nao liga? Solução: Verifique se o...
# 2   A BIOS é como o cérebro inicial do seu computa...
# ...

# %%
model = "models/embedding-001"

# %%
def embed_fn(title, text):
  return genai.embed_content(model=model,
                                 content=text,
                                 title=title,
                                 task_type="RETRIEVAL_DOCUMENT")["embedding"]

# %%
df["Embeddings"] = df.apply(lambda row: embed_fn(row["Titulo"], row["Conteudo"]), axis=1)
df
# Out:
#                                     Titulo  \
# 0                   Identificar o Problema
# 1                    O computador nao liga
# 2                             O que é bios
# 3                        Buscar Mais Ajuda
# 4   O computador liga, mas não inicializa.
# 5                  O computador está lento
# 6             O computador está congelando
# 7                        A tela está preta
# 8           Verificação de logs do Sistema
# 9              Ferramentas de diagnósticos
# 10                  Problema de desempenho
# 11     Verificação de arquivos corrompidos
# 12                  Verificação de drivers
# 13              Problemas de inicialização
# 14            Análise Avançada do Problema
#
#                                              Conteudo  \
# 0   Descreva o problema em detalhes: O que está ac...
# 1   O computador nao liga? Solução: Verifique se o...
# 2   A BIOS é como o cérebro inicial do seu computa...
# ...

# %%
def gerar_e_buscar_consulta(consulta, base, model):
  embedding_da_consulta = genai.embed_content(model=model,
                                 content=consulta,
                                 task_type="RETRIEVAL_QUERY")["embedding"]

  produtos_escalares = np.dot(np.stack(df["Embeddings"]), embedding_da_consulta)

  indice = np.argmax(produtos_escalares)
  return df.iloc[indice]["Conteudo"]

# %% [markdown]
# **FAÇA SUA PERGUNTA EM CONSULTA**

# %%
consulta = "meu computador está congelando"

trecho = gerar_e_buscar_consulta(consulta, df, model)
print(trecho)
# Out:
# Solução: Tente fechar todos os programas desnecessários que estejam em execução. Atualize os drivers do sistema. Verifique se há vírus ou malware no computador. Aumente a memória RAM do computador.

# %% [markdown]
# **EXECUTE AQUI PARA TER A RESPOSTA**

# %%
generation_config = {
  "temperature": 1,
  "candidate_count": 1
}

# %%
prompt = f"Reescreva esse texto como se tivesse explicando para uma pessoa comum sem muito entendimento sobre computadores,no formato de um passo a passo, sem adicionar muitas informações que não façam parte do texto: {trecho}"

model_2 = genai.GenerativeModel("gemini-1.0-pro",
                                generation_config=generation_config)
response = model_2.generate_content(prompt)
print(response.text)
# Out:
# **Passo a Passo para Melhorar Desempenho do Computador**
#
# **1. Feche Programas Desnecessários:**
#
# * Aperte o botão "Iniciar" na parte inferior da tela.
# * Clique em "Gerenciador de Tarefas".
# * Olhe para a guia "Processos" e procure por programas que você não está usando.
# * Clique no programa e escolha "Finalizar Tarefa".
#
# **2. Atualize Drivers do Sistema:**
#
# * Vá para o site do fabricante do seu computador.
# * Encontre a seção de "Downloads" ou "Suporte".
# * Procure por atualizações para seus drivers (programas que fazem seus componentes de hardware funcionarem).
# * Baixe e instale as atualizações.
#
# **3. Verifique Vírus e Malware:**
#
# * Abra seu software antivírus.
# * Execute uma verificação completa do sistema.
# * Se algum vírus ou malware for encontrado, remova-o.
#
# **4. Aumente a Memória RAM:**
#
# * Se o seu computador estiver lento, pode ser porque ele não tem memória RAM suficiente.
# ...
